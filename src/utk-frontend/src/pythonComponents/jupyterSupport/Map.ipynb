# %%
import sys
sys.path.append("../dataLoading/")

from mesh import *

# %%
uc = OSM.load_from_bbox([40.699768, -74.019904, 40.71135, -74.004712],layers=['buildings']) 
uc.view(width='100%', height='800px')
# Out:
# ...
#   0%|          | 0/208 [00:00<?, ?it/s]
# C:\Users\Gustavo\code\urbantk-react-ts\src\pythonComponents\dataLoading
#         <!DOCTYPE html>
#         <html lang="en">
#         <head>
#         <meta charset="UTF-8">
#         <title>urbantkmap widget</title>
#         </head>
#
#         <style>
#         #map {
#             width: 100%;
#             height: 800px;
#             margin: 0px;
#
#             overflow: hidden;
#         }
#         </style>
#
#         <body>
#         <div id="root"></div>
#         <script>
# ...
